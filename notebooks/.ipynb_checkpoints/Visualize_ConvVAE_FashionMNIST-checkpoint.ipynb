# %% [markdown]
# # Visualize Pretrained ConvVAE on Fashion-MNIST
# This notebook loads the pretrained ConvVAE model and visualizes reconstructions and new generated samples without retraining.

# %%
# Proje kök dizinine geç
# %cd "C:/Users/berat/OneDrive/Masaüstü/FashionConvVAE"
# Out:
# C:\Users\berat\OneDrive\Masaüstü\FashionConvVAE

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
import sys
sys.path.append("src")

# %%
import torch
from model import ConvVAE
from utils import visualize_reconstruction, sample_images
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load model
model = ConvVAE(latent_dim=32).to(device)
checkpoint = "src/checkpoints/convvae_fashionmnist.pth"
model.load_state_dict(torch.load(checkpoint, map_location=device))

model.eval()
print("✅ Pretrained ConvVAE checkpoint loaded.")
# Out:
# ✅ Pretrained ConvVAE checkpoint loaded.

# %%
# DataLoader for reconstructions
transform = transforms.Compose([transforms.ToTensor()])
test_ds = datasets.FashionMNIST("data/fashion-mnist", train=False, download=False, transform=transform)
test_loader = DataLoader(test_ds, batch_size=8, shuffle=True)

# %%
# Visualize Reconstructions
visualize_reconstruction(model, test_loader, device, num_images=8)

# %%
# Generate New Samples
sample_images(model, device, num_samples=16, latent_dim=32)
